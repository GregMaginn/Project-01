# %%
# import dependencies

from fycharts.SpotifyCharts import SpotifyCharts

api = SpotifyCharts()
api.top200Weekly(output_file = "top_200_weekly.csv", start = "2017-01-06", end = "2020-12-31", region = "us")
# Out:
# INFO : 18/03/2021 09:31:20 PM : Extracting top 200 weekly for 2017-01-06--2017-01-13 - us
# INFO : 18/03/2021 09:31:20 PM : Extracting top 200 weekly for 2017-01-13--2017-01-20 - us
# INFO : 18/03/2021 09:31:20 PM : Appending data to the file top_200_weekly.csv...
# INFO : 18/03/2021 09:31:20 PM : Done appending to the file top_200_weekly.csv!!!
# INFO : 18/03/2021 09:31:21 PM : Extracting top 200 weekly for 2017-01-20--2017-01-27 - us
# INFO : 18/03/2021 09:31:21 PM : Appending data to the file top_200_weekly.csv...
# INFO : 18/03/2021 09:31:21 PM : Done appending to the file top_200_weekly.csv!!!
# INFO : 18/03/2021 09:31:22 PM : Extracting top 200 weekly for 2017-01-27--2017-02-03 - us
# INFO : 18/03/2021 09:31:22 PM : Appending data to the file top_200_weekly.csv...
# INFO : 18/03/2021 09:31:22 PM : Done appending to the file top_200_weekly.csv!!!
# INFO : 18/03/2021 09:31:22 PM : Extracting top 200 weekly for 2017-02-03--2017-02-10 - us
# ...
