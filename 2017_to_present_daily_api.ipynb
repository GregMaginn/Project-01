# %%
# import dependencies

from fycharts.SpotifyCharts import SpotifyCharts

api = SpotifyCharts()
api.top200Daily(output_file = "top_200_daily.csv", start = "2017-01-01", end = "2020-12-31", region = "us")
# Out:
# INFO : 18/03/2021 09:25:34 PM : Extracting top 200 daily for 2017-01-01 - us
# INFO : 18/03/2021 09:25:35 PM : Extracting top 200 daily for 2017-01-02 - us
# INFO : 18/03/2021 09:25:35 PM : Appending data to the file top_200_daily.csv...
# INFO : 18/03/2021 09:25:35 PM : Done appending to the file top_200_daily.csv!!!
# INFO : 18/03/2021 09:25:37 PM : Extracting top 200 daily for 2017-01-03 - us
# INFO : 18/03/2021 09:25:37 PM : Appending data to the file top_200_daily.csv...
# INFO : 18/03/2021 09:25:37 PM : Done appending to the file top_200_daily.csv!!!
# INFO : 18/03/2021 09:25:37 PM : Extracting top 200 daily for 2017-01-04 - us
# INFO : 18/03/2021 09:25:37 PM : Appending data to the file top_200_daily.csv...
# INFO : 18/03/2021 09:25:37 PM : Done appending to the file top_200_daily.csv!!!
# INFO : 18/03/2021 09:25:38 PM : Extracting top 200 daily for 2017-01-05 - us
# INFO : 18/03/2021 09:25:38 PM : Appending data to the file top_200_daily.csv...
# ...
